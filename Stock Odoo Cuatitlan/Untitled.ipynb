# %%
import pandas as pd

# Ruta del archivo
archivo = "base_dashboard_rotacion.xlsx"

# Leer una hoja por nombre
df = pd.read_excel(archivo, sheet_name="dashboard_productos")

df.head()
# Out:
#   sku_madre                     producto_madre  ranking_ventas_3m  \
# 0    IQ1463                       Partybox 720                  1
# 1    IQ1095                        Ninja BN701                  2
# 2    IQ1251  XiaomiTV Box S tercera Generacion                  3
# 3    IQ1472               KODAK CHARMERA BLIND                  4
# 4     IQ973                     Ninja TB401LAA                  5
#
#    ranking_monto_3m ranking_top80  \
# 0                 1            #1
# 1                 2            #2
# 2                 3            #3
# 3                 4            #4
# 4                 5            #5
#
#                                   skus_sincronizados  \
# 0  IQ1463 | 67 | 6R-8M29-R0TS | A67 | AA67 | AB67...
# 1  HC-FY24-X6CH-COMBINADOSINETIQUETA | IQ1095 | 1...
# 2  11-9LWI-3CKA-COMBINADO SIN ETIQUETA | IQ1251 |...
# 3  IQ1472 | 1476 | 4W-MCSK-DBGG | 799991624530 | ...
# 4  IQ973 | 33 | 622356304900 | A33 | AA33 | AB33 ...
#
# ...

# %%
df["stock_odoo_cuautitlan"]
# Out:
# 0       10
# 1        6
# 2      108
# 3       33
# 4        5
#       ...
# 946      0
# 947      0
# 948      0
# 949      0
# 950      0
# Name: stock_odoo_cuautitlan, Length: 951, dtype: int64
